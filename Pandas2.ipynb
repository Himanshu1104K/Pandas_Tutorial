# %%
people = {
    "First" : ['Himanshu','Rahul','Shyam'],
    "Last"  : ['Kumar','Saini','Singh'],
    "Email" : ['HimanshuKumar@gmail.com','RahulSaini@gmail.com','ShyamSingh@gmail.com']
}

# %%
people['Email']
# Out:
# ['HimanshuKumar@gmail.com', 'RahulSaini@gmail.com', 'ShyamSingh@gmail.com']

# %%
people['Email'][1]
# Out:
# 'RahulSaini@gmail.com'

# %%
import pandas as pd

# %%
People_Df = pd.DataFrame(people)

# %%
People_Df
# Out:
#       First   Last                    Email
# 0  Himanshu  Kumar  HimanshuKumar@gmail.com
# 1     Rahul  Saini     RahulSaini@gmail.com
# 2     Shyam  Singh     ShyamSingh@gmail.com

# %%
df = pd.read_csv('CSV/survey_results_public.csv')
schema_df = pd.read_csv('CSV/survey_results_schema.csv')
df = df.iloc[0:1000]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = pd.read_csv('CSV/survey_results_public.csv')
#       2 schema_df = pd.read_csv('CSV/survey_results_schema.csv')
#       3 df = df.iloc[0:1000]
#
# ...

# %%
pd.set_option('display.max_columns',85)

# %% [markdown]
# For accessing a single column

# %%
df['ResponseId'].head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: ResponseId, dtype: int64

# %% [markdown]
# For accessing multiple columns

# %%
df[['ResponseId','MainBranch','Age']].head(3)
# Out:
#    ResponseId                      MainBranch              Age
# 0           1                   None of these  18-24 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  45-54 years old

# %% [markdown]
# For finding name of first 5  columns

# %%
df.columns[0:5]
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment'], dtype='object')

# %% [markdown]
# iloc (integer location of rows) for content of first five columns

# %%
# df.iloc[0][0:5]
# Same as above
df.iloc[[0],[0,1,2,3,4]]
# Out:
#    ResponseId     Q120     MainBranch              Age Employment
# 0           1  I agree  None of these  18-24 years old        NaN

# %% [markdown]
# For multiple rows

# %%
df.iloc[[0,1,2]]
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                                Remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
#
#                                         EdLevel  \
# 0                                           NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
# ...

# %% [markdown]
# loc (label location of rows)

# %%
df.loc[[0,1,2,3],['ResponseId']]
# Out:
#    ResponseId
# 0           1
# 1           2
# 2           3
# 3           4

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df['Knowledge_1'].value_counts()
# Out:
# Knowledge_1
# Agree                         257
# Strongly agree                176
# Neither agree nor disagree     39
# Disagree                       31
# Strongly disagree              10
# Name: count, dtype: int64

# %%
df.loc[0:5,'Knowledge_1':"Knowledge_8"]
# Out:
#       Knowledge_1                 Knowledge_2     Knowledge_3  \
# 0             NaN                         NaN             NaN
# 1  Strongly agree                       Agree  Strongly agree
# 2  Strongly agree  Neither agree nor disagree           Agree
# 3  Strongly agree           Strongly disagree  Strongly agree
# 4           Agree              Strongly agree           Agree
# 5           Agree              Strongly agree        Disagree
#
#                   Knowledge_4                 Knowledge_5  \
# 0                         NaN                         NaN
# 1                       Agree                       Agree
# 2                       Agree                       Agree
# 3              Strongly agree                       Agree
# 4                       Agree  Neither agree nor disagree
# 5  Neither agree nor disagree           Strongly disagree
#
#                   Knowledge_6     Knowledge_7     Knowledge_8
# ...

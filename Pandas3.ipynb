# %%
import pandas as pd

# %%
people = {
    "First" : ['Himanshu','Rahul','Shyam'],
    "Last"  : ['Kumar','Saini','Singh'],
    "Email" : ['HimanshuKumar@gmail.com','RahulSaini@gmail.com','ShyamSingh@gmail.com']
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#       First   Last                    Email
# 0  Himanshu  Kumar  HimanshuKumar@gmail.com
# 1     Rahul  Saini     RahulSaini@gmail.com
# 2     Shyam  Singh     ShyamSingh@gmail.com

# %%
df.set_index("Email")
# Out:
#                             First   Last
# Email
# HimanshuKumar@gmail.com  Himanshu  Kumar
# RahulSaini@gmail.com        Rahul  Saini
# ShyamSingh@gmail.com        Shyam  Singh

# %%
df
# Out:
#       First   Last                    Email
# 0  Himanshu  Kumar  HimanshuKumar@gmail.com
# 1     Rahul  Saini     RahulSaini@gmail.com
# 2     Shyam  Singh     ShyamSingh@gmail.com

# %% [markdown]
# for Permanent replacement

# %%
df.set_index('Email',inplace=True)

# %%
df
# Out:
#                             First   Last
# Email
# HimanshuKumar@gmail.com  Himanshu  Kumar
# RahulSaini@gmail.com        Rahul  Saini
# ShyamSingh@gmail.com        Shyam  Singh

# %%
df.index
# Out:
# Index(['HimanshuKumar@gmail.com', 'RahulSaini@gmail.com',
#        'ShyamSingh@gmail.com'],
#       dtype='object', name='Email')

# %% [markdown]
# For reseting the indexes

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                      Email     First   Last
# 0  HimanshuKumar@gmail.com  Himanshu  Kumar
# 1     RahulSaini@gmail.com     Rahul  Saini
# 2     ShyamSingh@gmail.com     Shyam  Singh

# %% [markdown]
# For setting up index during reading of a csv file

# %%
newDf = pd.read_csv('CSV/survey_results_public.csv',index_col='ResponseId')

# %%
newDf.head(3)
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                                Remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                              CodingActivities  \
# ResponseId
# 1                                                         NaN
# 2           Hobby;Contribute to open-source projects;Boots...
# 3           Hobby;Professional development or self-paced l...
#
#                                                  EdLevel  \
# ResponseId
# ...

# %%
schema_df = pd.read_csv('CSV/survey_results_schema.csv',index_col='qname')

# %%
schema_df.head()
# Out:
#            qid                                           question force_resp  \
# qname
# AIAcc   QID324  For the AI tools you use as part of your devel...      False
# AIBen   QID316  How much do you trust the accuracy of the outp...      False
# AIDev   QID328  Which <b>AI-powered developer tools</b> did yo...      False
# AINext  QID320  Thinking about how your workflow and process c...      False
# AIOpen  QID321  Please describe how you would expect your work...      False
#
#           type selector
# qname
# AIAcc       MC     MAVR
# AIBen       MC     SAVR
# AIDev   Matrix   Likert
# AINext  Matrix   Likert
# AIOpen      TE       SL

# %%
schema_df.sort_index(inplace=True)

# %%
import pandas as pd

# %%
people = {
    "First" : ['Himanshu','Abdul','Rahul','Shyam'],
    "Last"  : ['Kumar','Khan','Kumar','Kumar'],
    "Email" : ['HimanshuKumar@gmail.com','AbdulKhan@gmail.com','RahulSaini@gmail.com','ShyamSingh@gmail.com']
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#       First   Last                    Email
# 0  Himanshu  Kumar  HimanshuKumar@gmail.com
# 1     Abdul   Khan      AbdulKhan@gmail.com
# 2     Rahul  Kumar     RahulSaini@gmail.com
# 3     Shyam  Kumar     ShyamSingh@gmail.com

# %%
df.sort_values(by='First',ascending=False)
# Out:
#       First   Last                    Email
# 3     Shyam  Kumar     ShyamSingh@gmail.com
# 2     Rahul  Kumar     RahulSaini@gmail.com
# 0  Himanshu  Kumar  HimanshuKumar@gmail.com
# 1     Abdul   Khan      AbdulKhan@gmail.com

# %%
df.sort_values(by=['Last','First'],ascending=[False,True],inplace=True)

# %%
df
# Out:
#       First   Last                    Email
# 0  Himanshu  Kumar  HimanshuKumar@gmail.com
# 2     Rahul  Kumar     RahulSaini@gmail.com
# 3     Shyam  Kumar     ShyamSingh@gmail.com
# 1     Abdul   Khan      AbdulKhan@gmail.com

# %%
df.sort_index()
# Out:
#       First   Last                    Email
# 0  Himanshu  Kumar  HimanshuKumar@gmail.com
# 1     Abdul   Khan      AbdulKhan@gmail.com
# 2     Rahul  Kumar     RahulSaini@gmail.com
# 3     Shyam  Kumar     ShyamSingh@gmail.com

# %%
df_survey = pd.read_csv('CSV/survey_results_public.csv')

# %%
df_survey.head(5)
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df_survey.sort_values(by=['Country','CompTotal'],inplace=True)

# %%
df_survey[['Country','CompTotal']].head(20).dropna()
# Out:
#            Country    CompTotal
# 59005  Afghanistan          0.0
# 67793  Afghanistan          0.0
# 61075  Afghanistan          1.0
# 2641   Afghanistan        123.0
# 37955  Afghanistan       3600.0
# 39426  Afghanistan       4200.0
# 41678  Afghanistan      56666.0
# 86038  Afghanistan      68000.0
# 53321  Afghanistan      69420.0
# 36048  Afghanistan      80000.0
# 17872  Afghanistan     100000.0
# 57361  Afghanistan     200000.0
# 1334   Afghanistan     210000.0
# 88347  Afghanistan  932464379.0

# %%
df_survey.nlargest(5,'CompTotal')
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 56322       56323  I agree                     I am a developer by profession
# 18463       18464  I agree                     I am a developer by profession
# 43556       43557  I agree                     I am a developer by profession
# 49553       49554  I agree  I am not primarily a developer, but I write co...
# 35779       35780  I agree                     I am a developer by profession
#
#                    Age           Employment RemoteWork  \
# 56322  25-34 years old  Employed, full-time  In-person
# 18463  25-34 years old  Employed, full-time  In-person
# 43556  18-24 years old  Employed, full-time     Remote
# 49553  25-34 years old  Employed, full-time  In-person
# 35779  25-34 years old  I prefer not to say        NaN
#
#                                         CodingActivities  \
# 56322  Hobby;Contribute to open-source projects;Boots...
# ...

# %%
df_survey.fillna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_survey.fillna()
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:7293, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7286         if ctr <= ref_count:
#    7287             warnings.warn(
#    7288                 _chained_assignment_warning_method_msg,
#    7289                 FutureWarning,
#    7290                 stacklevel=2,
#    7291             )
# -> 7293 value, method = validate_fillna_kwargs(value, method)
#    7294 if method is not None:
#    7295     warnings.warn(
#    7296         f"{type(self).__name__}.fillna with 'method' is deprecated and "
#    7297         "will raise in a future version. Use obj.ffill() or obj.bfill() "
#    (...)
#    7300         stacklevel=find_stack_level(),
# ...
